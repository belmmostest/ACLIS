# %% [markdown]
# # Test Ingestion Pipeline

# %%
import os, sys
sys.path.append(os.path.abspath('../'))

# %%
from src.pipeline.ingestion import IngestionPipeline

# %%
ip = IngestionPipeline()
data = ip.run()
print('Scored data shape:', data['scored_data'].shape)
print('Feature metadata shape:', data['feature_metadata'].shape)
print('Number of offers loaded:', len(data['offers']))
print('Offers metadata shape:', data['offers_metadata'].shape)
# Out:
# Scored data shape: (199, 58)
# Feature metadata shape: (58, 5)
# Number of offers loaded: 7
# Offers metadata shape: (33, 2)

# %%
data['feature_metadata']
# Out:
#                                          Column  ...         Product
# 0                                   customer_id  ...             NaN
# 1                                    month_year  ...             NaN
# 2     avg_3mth_lag_fxd_brdbnd_total_download_gb  ...  Unifi/Streamyx
# 3            avg_3mth_fxd_brdbnd_total_sessions  ...  Unifi/Streamyx
# 4                 min_months_until_contract_end  ...      Unifi/WEBE
# 5                         payment_mode_cash_cnt  ...             NaN
# 6                 max_months_until_contract_end  ...      Unifi/WEBE
# 7                      lag2_sum_net_revenue_amt  ...             NaN
# 8                  payment_mode_credit_card_cnt  ...             NaN
# 9                                lag2_sum_price  ...             NaN
# 10                  lag2_sum_unifi_stmx_rev_amt  ...  Unifi/Streamyx
# 11                     lag2_sum_monthly_charges  ...             NaN
# 12                         lag2_sum_inv_tax_amt  ...             NaN
# ...
